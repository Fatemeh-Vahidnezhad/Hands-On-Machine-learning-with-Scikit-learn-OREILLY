# %% [markdown]
# # MLP Regression

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

# %%
housing = fetch_california_housing()

# %%
x_train_ful, x_test, y_train_ful, y_test = train_test_split(housing.data, housing.target)
x_train, x_valid, y_train, y_valid = train_test_split(x_train_ful, y_train_ful)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_valid = scaler.transform(x_valid)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation = 'relu', input_shape = x_train.shape[1:]),
    keras.layers.Dense(1)      
])
model.compile(loss = 'mean_squared_error', optimizer = 'sgd')
history = model.fit(x_train, y_train, epochs = 20, validation_data = (x_valid, y_valid))
mse_test = model.evaluate(x_test, y_test)
x_new = x_test[:3]
y_pred = model.predict(x_new)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021B2E133F78> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021B2E133F78> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# 11610/11610 [==============================] - 4s 330us/sample - loss: 0.8369 - val_loss: 0.5944
# Epoch 2/20
# 11610/11610 [==============================] - 2s 181us/sample - loss: 0.4983 - val_loss: 0.4718
# Epoch 3/20
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.4635 - val_loss: 0.4752
# Epoch 4/20
# 11610/11610 [==============================] - 2s 185us/sample - loss: 0.4463 - val_loss: 0.4344
# Epoch 5/20
# 11610/11610 [==============================] - 2s 187us/sample - loss: 0.4254 - val_loss: 0.4242
# Epoch 6/20
# 11610/11610 [==============================] - 2s 195us/sample - loss: 0.4130 - val_loss: 0.4267
# Epoch 7/20
# 11610/11610 [==============================] - 3s 228us/sample - loss: 0.4077 - val_loss: 0.4121
# Epoch 8/20
# 11610/11610 [==============================] - 2s 215us/sample - loss: 0.4052 - val_loss: 0.4206
# Epoch 9/20
# 11610/11610 [==============================] - 2s 212us/sample - loss: 0.3957 - val_loss: 0.3969
# Epoch 10/20
# 11610/11610 [==============================] - 3s 224us/sample - loss: 0.3950 - val_loss: 0.3935
# Epoch 11/20
# 11610/11610 [==============================] - 2s 213us/sample - loss: 0.3890 - val_loss: 0.4000
# Epoch 12/20
# 11610/11610 [==============================] - 2s 214us/sample - loss: 0.3877 - val_loss: 0.3946
# Epoch 13/20
# 11610/11610 [==============================] - 2s 211us/sample - loss: 0.3875 - val_loss: 0.3781
# Epoch 14/20
# 11610/11610 [==============================] - 2s 212us/sample - loss: 0.3836 - val_loss: 0.3833
# Epoch 15/20
# 11610/11610 [==============================] - 2s 212us/sample - loss: 0.3759 - val_loss: 0.3765
# Epoch 16/20
# 11610/11610 [==============================] - 2s 212us/sample - loss: 0.3769 - val_loss: 0.3765
# Epoch 17/20
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3743 - val_loss: 0.3812
# Epoch 18/20
# 11610/11610 [==============================] - 2s 215us/sample - loss: 0.3719 - val_loss: 0.3832
# Epoch 19/20
# 11610/11610 [==============================] - 2s 211us/sample - loss: 0.3685 - val_loss: 0.3724
# Epoch 20/20
# 11610/11610 [==============================] - 2s 212us/sample - loss: 0.3680 - val_loss: 0.3684
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
x_train.shape[1:]
# Out:
# (8,)

# %% [markdown]
# # Wide and Deep Neural Network

# %%
input_ = keras.layers.Input(shape = x_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation = 'relu')(input_)
hidden2 = keras.layers.Dense(30, activation = 'relu')(hidden1)
concat = keras.layers.Concatenate()([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs = [input_], outputs = [output])

# %%
model.compile(loss = 'mean_squared_error', optimizer = 'sgd')
history = model.fit(x_train, y_train, epochs = 20, validation_data = (x_valid, y_valid))
mse_test = model.evaluate(x_test, y_test)
x_new = x_test[:3]
y_pred = model.predict(x_new)

# %% [raw]
# two inputs

# %%
input_A = keras.layers.Input(shape = [5], name = 'wide_input')
input_B = keras.layers.Input(shape = [6], name = 'deep_input')

hidden1 = keras.layers.Dense(30, activation = 'relu')(input_A)
hidden2 = keras.layers.Dense(30, activation = 'relu')(hidden1)
concat = keras.layers.Concatenate()([input_B, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs = [input_A, input_B], outputs = [output])

# %%
model.compile(loss = 'mse', optimizer = keras.optimizers.SGD(lr = 1e-3))

x_train_A, x_train_B = x_train[:,:5], x_train[:,2:]  #Features in two groups have overlap
x_test_A, x_test_B = x_test[:,:5], x_test[:,2:]  
x_valid_A, x_valid_B = x_valid[:,:5], x_valid[:,2:]  
x_new_A, x_new_B = x_test_A[:3], x_test_B[:3]

# %%
history = model.fit((x_train_A, x_train_B), y_train,epochs = 20, validation_data = ((x_valid_A, x_valid_B), y_valid))
mse_test = model.evaluate((x_test_A, x_test_B), y_test)
y_pred = model.predict((x_new_A, x_new_B))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021B2DD75EE8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021B2DD75EE8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# 11610/11610 [==============================] - 1s 109us/sample - loss: 1.6842 - val_loss: 1.0889
# Epoch 2/20
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.8361 - val_loss: 0.8209
# Epoch 3/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.7522 - val_loss: 0.7320
# Epoch 4/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.7028 - val_loss: 0.6857
# Epoch 5/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6674 - val_loss: 0.6543
# Epoch 6/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6404 - val_loss: 0.6299
# Epoch 7/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6184 - val_loss: 0.6092
# Epoch 8/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6006 - val_loss: 0.5926
# Epoch 9/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5857 - val_loss: 0.5805
# Epoch 10/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5742 - val_loss: 0.5686
# Epoch 11/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5634 - val_loss: 0.5611
# Epoch 12/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5555 - val_loss: 0.5551
# Epoch 13/20
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5478 - val_loss: 0.5463
# Epoch 14/20
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5409 - val_loss: 0.5392
# Epoch 15/20
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.5343 - val_loss: 0.5352
# Epoch 16/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5294 - val_loss: 0.5290
# Epoch 17/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5247 - val_loss: 0.5255
# Epoch 18/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5202 - val_loss: 0.5212
# Epoch 19/20
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5158 - val_loss: 0.5195
# Epoch 20/20
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5117 - val_loss: 0.5151
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %% [raw]
# extra output

# %%
input_A = keras.layers.Input(shape = [5], name = 'wide_input')
input_B = keras.layers.Input(shape = [6], name = 'deep_input')

hidden1 = keras.layers.Dense(30, activation = 'relu')(input_A)
hidden2 = keras.layers.Dense(30, activation = 'relu')(hidden1)
concat = keras.layers.Concatenate()([input_B, hidden2])

output = keras.layers.Dense(1, name = "main_output")(concat)
aux_output = keras.layers.Dense(1, name = "aux_output")(hidden2)
model = keras.Model(inputs = [input_A, input_B], outputs = [output, aux_output])

# %%
model.compile(loss = ['mse','mse'], optimizer ='sgd', loss_weights = [0.9, 0.1])

x_train_A, x_train_B = x_train[:,:5], x_train[:,2:]  #Features in two groups have overlap
x_test_A, x_test_B = x_test[:,:5], x_test[:,2:]  
x_valid_A, x_valid_B = x_valid[:,:5], x_valid[:,2:]  
x_new_A, x_new_B = x_test_A[:3], x_test_B[:3]

# %% [raw]
# save and restore a model

# %%
history = model.fit([x_train_A, x_train_B], [y_train, y_train] ,epochs = 20,
                    validation_data = ([x_valid_A, x_valid_B], [y_valid, y_valid]))
model.save('my_keras_model.h5')
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# 11610/11610 [==============================] - 1s 74us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 2/20
# 11610/11610 [==============================] - 1s 83us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 3/20
# 11610/11610 [==============================] - 1s 76us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 4/20
# 11610/11610 [==============================] - 1s 80us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 5/20
# 11610/11610 [==============================] - 1s 77us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 6/20
# 11610/11610 [==============================] - 1s 77us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 7/20
# 11610/11610 [==============================] - 1s 75us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 8/20
# 11610/11610 [==============================] - 1s 77us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 9/20
# 11610/11610 [==============================] - 1s 75us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 10/20
# 11610/11610 [==============================] - 1s 75us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 11/20
# 11610/11610 [==============================] - 1s 80us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 12/20
# 11610/11610 [==============================] - 1s 71us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 13/20
# 11610/11610 [==============================] - 1s 72us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 14/20
# 11610/11610 [==============================] - 1s 70us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 15/20
# 11610/11610 [==============================] - 1s 70us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 16/20
# 11610/11610 [==============================] - 1s 76us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 17/20
# 11610/11610 [==============================] - 1s 76us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 18/20
# 11610/11610 [==============================] - 1s 76us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 19/20
# 11610/11610 [==============================] - 1s 78us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan
# Epoch 20/20
# 11610/11610 [==============================] - 1s 70us/sample - loss: nan - main_output_loss: nan - aux_output_loss: nan - val_loss: nan - val_main_output_loss: nan - val_aux_output_loss: nan

# %%
model = keras.models.load_model("my_keras_model.h5")
total_loss, main_loss, aux_loss = model.evaluate([x_test_A, x_test_B], [y_test, y_test])
y_pred_main, y_pred_axu = model.predict([x_new_A, x_new_B])
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %% [markdown]
# # TensorBoard for visualizing

# %%
import os
root_logdir = os.path.join(os.curdir, "my_logs")
def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()

# %%
input_ = keras.layers.Input(shape = x_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation = 'relu')(input_)
hidden2 = keras.layers.Dense(30, activation = 'relu')(hidden1)
concat = keras.layers.Concatenate()([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs = [input_], outputs = [output])

model.compile(loss = 'mean_squared_error', optimizer = 'sgd')

# %%
#build and compile your model
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
history = model.fit(x_train, y_train, epochs = 20, validation_data = (x_valid, y_valid), callbacks=[tensorboard_cb])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002AFEF094B88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002AFEF094B88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# 11610/11610 [==============================] - 4s 333us/sample - loss: 0.7836 - val_loss: 1.3253
# Epoch 2/20
# 11610/11610 [==============================] - 2s 134us/sample - loss: 0.8472 - val_loss: 2.0417
# Epoch 3/20
# 11610/11610 [==============================] - 3s 232us/sample - loss: 5.7838 - val_loss: 0.6135
# Epoch 4/20
# 11610/11610 [==============================] - 3s 234us/sample - loss: 0.8275 - val_loss: 0.4951
# Epoch 5/20
# 11610/11610 [==============================] - 2s 195us/sample - loss: 0.5150 - val_loss: 0.4524
# Epoch 6/20
# 11610/11610 [==============================] - 3s 224us/sample - loss: 0.4350 - val_loss: 0.4413
# Epoch 7/20
# 11610/11610 [==============================] - 3s 234us/sample - loss: 0.5298 - val_loss: 0.4170
# Epoch 8/20
# 11610/11610 [==============================] - 3s 236us/sample - loss: 0.4082 - val_loss: 0.4274
# Epoch 9/20
# 11610/11610 [==============================] - 3s 239us/sample - loss: 0.3962 - val_loss: 0.4161
# Epoch 10/20
# 11610/11610 [==============================] - 3s 218us/sample - loss: 0.4765 - val_loss: 0.3771
# Epoch 11/20
# 11610/11610 [==============================] - 3s 233us/sample - loss: 0.3808 - val_loss: 0.3929
# Epoch 12/20
# 11610/11610 [==============================] - 3s 232us/sample - loss: 0.5469 - val_loss: 0.3657
# Epoch 13/20
# 11610/11610 [==============================] - 3s 221us/sample - loss: 0.3737 - val_loss: 0.3610
# Epoch 14/20
# 11610/11610 [==============================] - 3s 232us/sample - loss: 0.3628 - val_loss: 0.3892
# Epoch 15/20
# 11610/11610 [==============================] - 3s 233us/sample - loss: 0.3932 - val_loss: 0.3908
# Epoch 16/20
# 11610/11610 [==============================] - 3s 233us/sample - loss: 0.3768 - val_loss: 0.3730
# Epoch 17/20
# 11610/11610 [==============================] - 3s 234us/sample - loss: 0.4518 - val_loss: 0.3934
# Epoch 18/20
# 11610/11610 [==============================] - 3s 233us/sample - loss: 0.4902 - val_loss: 0.3504
# Epoch 19/20
# 11610/11610 [==============================] - 3s 235us/sample - loss: 0.3750 - val_loss: 0.3484
# Epoch 20/20
# 11610/11610 [==============================] - 3s 232us/sample - loss: 0.3474 - val_loss: 0.3902

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %tensorboard --logdir=./my_logs --port=6006
# Out:
# Reusing TensorBoard on port 6006 (pid 368), started 0:07:45 ago. (Use '!kill 368' to kill it.)
#       <iframe id="tensorboard-frame-1192284badbf453c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1192284badbf453c");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
